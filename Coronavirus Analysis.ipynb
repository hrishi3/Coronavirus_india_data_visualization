# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/gmqr4kpnfzeiyd7no3nrumydlfyzix')

# %%
df
df['Date']=pd.to_datetime(df.Date)
df
# Out:
#       Country_Region  Case_Type       Date  ...  Province_State      Lat      Long
# 0                 US  Confirmed 2020-03-23  ...           Idaho  44.2405 -114.4788
# 1                 US     Deaths 2020-03-23  ...           Idaho  44.2405 -114.4788
# 2                 US  Confirmed 2020-03-24  ...           Idaho  44.2405 -114.4788
# 3                 US     Deaths 2020-03-24  ...           Idaho  44.2405 -114.4788
# 4                 US     Deaths 2020-02-28  ...           Idaho  44.2405 -114.4788
# ...              ...        ...        ...  ...             ...      ...       ...
# 36455       Djibouti  Confirmed 2020-01-27  ...             NaN  11.8251   42.5903
# 36456       Djibouti  Confirmed 2020-01-26  ...             NaN  11.8251   42.5903
# 36457       Djibouti  Confirmed 2020-01-25  ...             NaN  11.8251   42.5903
# 36458       Djibouti  Confirmed 2020-01-24  ...             NaN  11.8251   42.5903
# 36459       Djibouti  Confirmed 2020-01-23  ...             NaN  11.8251   42.5903
#
# [36460 rows x 11 columns]

# %%
d=df.pivot_table('Cases',['Country_Region','Date','Difference'],'Case_Type')
d
# Out:
# Case_Type                             Confirmed  Deaths
# Country_Region Date       Difference
# Afghanistan    2020-01-23 0                 0.0     0.0
#                2020-01-24 0                 0.0     0.0
#                2020-01-25 0                 0.0     0.0
#                2020-01-26 0                 0.0     0.0
#                2020-01-27 0                 0.0     0.0
# ...                                         ...     ...
# Zimbabwe       2020-03-21 2                 3.0     NaN
#                2020-03-22 0                 3.0     0.0
#                2020-03-23 0                 3.0     NaN
#                           1                 NaN     1.0
#                2020-03-24 0                 3.0     1.0
#
# [14459 rows x 2 columns]

# %%
df1=df[df['Country_Region']=='India']
df1
# Out:
#       Country_Region  Case_Type       Date  ...  Province_State   Lat  Long
# 21952          India     Deaths 2020-03-09  ...             NaN  21.0  78.0
# 21953          India     Deaths 2020-03-08  ...             NaN  21.0  78.0
# 21954          India     Deaths 2020-03-07  ...             NaN  21.0  78.0
# 21955          India     Deaths 2020-03-06  ...             NaN  21.0  78.0
# 21956          India     Deaths 2020-03-05  ...             NaN  21.0  78.0
# ...              ...        ...        ...  ...             ...   ...   ...
# 22071          India  Confirmed 2020-01-27  ...             NaN  21.0  78.0
# 22072          India  Confirmed 2020-01-26  ...             NaN  21.0  78.0
# 22073          India  Confirmed 2020-01-25  ...             NaN  21.0  78.0
# 22074          India  Confirmed 2020-01-24  ...             NaN  21.0  78.0
# 22075          India  Confirmed 2020-01-23  ...             NaN  21.0  78.0
#
# [124 rows x 11 columns]

# %%
d1=df1.pivot_table('Cases',['Country_Region','Date'],'Case_Type')
d1
# Out:
# Case_Type                  Confirmed  Deaths
# Country_Region Date
# India          2020-01-23          0       0
#                2020-01-24          0       0
#                2020-01-25          0       0
#                2020-01-26          0       0
#                2020-01-27          0       0
# ...                              ...     ...
#                2020-03-20        244       5
#                2020-03-21        330       4
#                2020-03-22        396       7
#                2020-03-23        499      10
#                2020-03-24        536      10
#
# [62 rows x 2 columns]

# %%
d2=pd.DataFrame(d1.to_records())
d2
d2=d2.iloc[38:]
d2
# Out:
#    Country_Region       Date  Confirmed  Deaths
# 38          India 2020-03-01          3       0
# 39          India 2020-03-02          5       0
# 40          India 2020-03-03          5       0
# 41          India 2020-03-04         28       0
# 42          India 2020-03-05         30       0
# 43          India 2020-03-06         31       0
# 44          India 2020-03-07         34       0
# 45          India 2020-03-08         39       0
# 46          India 2020-03-09         43       0
# 47          India 2020-03-10         56       0
# 48          India 2020-03-11         62       1
# 49          India 2020-03-12         73       1
# 50          India 2020-03-13         82       2
# 51          India 2020-03-14        102       2
# 52          India 2020-03-15        113       2
# 53          India 2020-03-16        119       2
# 54          India 2020-03-17        142       3
# 55          India 2020-03-18        156       3
# 56          India 2020-03-19        194       4
# 57          India 2020-03-20        244       5
# 58          India 2020-03-21        330       4
# 59          India 2020-03-22        396       7
# 60          India 2020-03-23        499      10
# 61          India 2020-03-24        536      10

# %%
fig, ax = plt.subplots()
d2.plot(kind='line', x='Date', y='Confirmed', ax=ax)
d2.plot(kind='line', x='Date', y='Deaths', ax=ax)
ax.grid(axis='both',linestyle='-', linewidth='0.5', color='red')

# Turn on the minor TICKS, which are required for the minor GRID
#ax.minorticks_on()

# Customize the major grid#
ax.grid(which='major', linestyle=':', linewidth='0.5', color='red')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

# %%
df2=df1[df1['Case_Type']=='Confirmed']
df2.head()
# Out:
#       Country_Region  Case_Type       Date  ...  Province_State   Lat  Long
# 22014          India  Confirmed 2020-03-09  ...             NaN  21.0  78.0
# 22015          India  Confirmed 2020-03-08  ...             NaN  21.0  78.0
# 22016          India  Confirmed 2020-03-07  ...             NaN  21.0  78.0
# 22017          India  Confirmed 2020-03-06  ...             NaN  21.0  78.0
# 22018          India  Confirmed 2020-03-05  ...             NaN  21.0  78.0
#
# [5 rows x 11 columns]

# %%
df2=df2.sort_values(by='Date')
df2['Date']=df2['Date'].astype('datetime64[ns]')

# %%
df3=df2.filter(['Date','Cases','Difference'],axis=1)

df3
df3=df3.iloc[38:]
df3.describe
# Out:
# <bound method NDFrame.describe of             Date  Cases  Difference
# 22037 2020-03-01      3           0
# 22026 2020-03-02      5           2
# 22020 2020-03-03      5           0
# 22019 2020-03-04     28          23
# 22018 2020-03-05     30           2
# 22017 2020-03-06     31           1
# 22016 2020-03-07     34           3
# 22015 2020-03-08     39           5
# 22014 2020-03-09     43           4
# 22036 2020-03-10     56          13
# 22035 2020-03-11     62           6
# 22034 2020-03-12     73          11
# 22033 2020-03-13     82           9
# 22032 2020-03-14    102          20
# 22031 2020-03-15    113          11
# 22030 2020-03-16    119           6
# 22029 2020-03-17    142          23
# 22028 2020-03-18    156          14
# 22027 2020-03-19    194          38
# 22025 2020-03-20    244          50
# 22024 2020-03-21    330          86
# 22023 2020-03-22    396          66
# 22022 2020-03-23    499         103
# 22021 2020-03-24    536          37>

# %%
import matplotlib.pyplot as plt
plt.plot(df3['Date'].dt.day,df3['Cases'])
plt.xlabel('Date(from March 1st)')
plt.ylabel('Cases')
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')

# %%
plt.plot(df3['Date'].dt.day,df3['Difference'])
plt.xlabel('Date(from March 1st)')
plt.ylabel('New cases on day')
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='1', color='red')

# %%
fig, ax = plt.subplots()
df3.plot(kind='line', x='Date', y='Cases', ax=ax)
df3.plot(kind='line', x='Date', y='Difference', ax=ax)
ax.grid(axis='both',linestyle='-', linewidth='0.5', color='red')

# Turn on the minor TICKS, which are required for the minor GRID
#ax.minorticks_on()

# Customize the major grid#
ax.grid(which='major', linestyle=':', linewidth='0.5', color='red')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

# %%
fig, ax = plt.subplots()
df3.plot(kind='line', x='Date', y='Difference', ax=ax)
ax.grid(axis='both',linestyle='-', linewidth='0.5', color='red')

# Turn on the minor TICKS, which are required for the minor GRID
#ax.minorticks_on()

# Customize the major grid#
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
from google.colab import files
plt.savefig("abc.png")
files.download("abc.png")
